# %% [markdown]
# # Cleaning Data Exercises
#
# For the exercises, you will be cleaning data in your chosen data set. [Towards Data Science](https://towardsdatascience.com/data-cleaning-in-python-the-ultimate-guide-2020-c63b88bf0a0d) outlines the steps we should take to clean data using a different data set from Kaggle. While you should use this article as a reference, make sure not to copy paste as the two data sets are very different!
#
# To start cleaning data, we first need to create a dataframe from the CSV and print out any relevant info to make sure our dataframe is ready to go.

# %%
# Import pandas and any other libraries you need here. HINT: Check out the article to see what they imported to get started!

import pandas as pd

import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

pd.options.mode.chained_assignment = None

url = 'https://raw.githubusercontent.com/e3la/cleaning-data/main/Rat_Sightings.csv'
# Create a new dataframe from your CSV

df = pd.read_csv(url)

# %%
# Print out any information you need to understand your dataframe

df.columns
# Out:
# Index(['Unique Key', 'Created Date', 'Closed Date', 'Agency', 'Agency Name',
#        'Complaint Type', 'Descriptor', 'Location Type', 'Incident Zip',
#        'Incident Address', 'Street Name', 'Cross Street 1', 'Cross Street 2',
#        'Intersection Street 1', 'Intersection Street 2', 'Address Type',
#        'City', 'Landmark', 'Facility Type', 'Status', 'Due Date',
#        'Resolution Action Updated Date', 'Community Board', 'Borough',
#        'X Coordinate (State Plane)', 'Y Coordinate (State Plane)',
#        'Park Facility Name', 'Park Borough', 'School Name', 'School Number',
#        'School Region', 'School Code', 'School Phone Number', 'School Address',
#        'School City', 'School State', 'School Zip', 'School Not Found',
#        'School or Citywide Complaint', 'Vehicle Type', 'Taxi Company Borough',
#        'Taxi Pick Up Location', 'Bridge Highway Name',
#        'Bridge Highway Direction', 'Road Ramp', 'Bridge Highway Segment',
# ...

# %% [markdown]
# Now you have a dataframe set up, you are ready to dive in and start cleaning!

# %% [markdown]
# ## Missing Data
#
# In the Towards Data Science article, they list 3 techniques for detecting any missing data frame. Try all three before deciding on a way to solve any missing data issues.

# %%
# Plot a heatmap of any missing data


cols = df.columns[30:] # first 30 columns
colours = ['#000099', '#ffff00'] # specify the colours - yellow is missing. blue is not missing.
sns.heatmap(df[cols].isnull(), cmap=sns.color_palette(colours))
# Out:
# <Axes: >

# %%
# Try out a missing data percentage list!


for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# Unique Key - 0%
# Created Date - 0%
# Closed Date - 11%
# Agency - 0%
# Agency Name - 0%
# Complaint Type - 0%
# Descriptor - 0%
# Location Type - 0%
# Incident Zip - 0%
# Incident Address - 9%
# Street Name - 9%
# Cross Street 1 - 16%
# Cross Street 2 - 16%
# Intersection Street 1 - 91%
# Intersection Street 2 - 91%
# Address Type - 0%
# City - 0%
# Landmark - 100%
# Facility Type - 100%
# Status - 0%
# Due Date - 0%
# Resolution Action Updated Date - 0%
# Community Board - 0%
# Borough - 0%
# X Coordinate (State Plane) - 1%
# Y Coordinate (State Plane) - 1%
# Park Facility Name - 0%
# Park Borough - 0%
# School Name - 0%
# School Number - 0%
# School Region - 0%
# School Code - 0%
# School Phone Number - 0%
# School Address - 0%
# School City - 0%
# School State - 0%
# School Zip - 0%
# School Not Found - 1%
# School or Citywide Complaint - 100%
# Vehicle Type - 100%
# Taxi Company Borough - 100%
# Taxi Pick Up Location - 100%
# Bridge Highway Name - 100%
# ...

# %%
# Plot a missing data histogram

missing_by_row = df.isna().sum(axis='columns')


# then based on the indicator, plot the histogram of missing values
missing_by_row.hist(bins=50)
# Out:
# <Axes: >

# %% [markdown]
# Now that you have tried all 3 techniques for detecting missing data, did you find any? Reading through the article, which solution do you think will help you clean the data set and handle the missing data? Try out your solution below!
#
# My solution is

# %%
# Handle any missing data in your dataframe.

pct_missing[pct_missing > .1]
df_less_missing_cols = df.loc[:, pct_missing <= .3].copy()
df_less_missing_cols.shape

df2 = df_less_missing_cols

# %% [markdown]
# ## Irregular Data
#
# With missing data out of the way, turn your attention to any outliers. Just as we did for missing data, we first need to detect the outliers. The article outlines the top techniques for finding outliers in a dataset.

# %%
# Plot a histogram to see if there are any outliers.
df2_nomissing = df2.filter(regex='^(?!.*_ismissing)')
df2_nomissing.columns
# Out:
# Index(['Unique Key', 'Created Date', 'Closed Date', 'Agency', 'Agency Name',
#        'Complaint Type', 'Descriptor', 'Location Type', 'Incident Zip',
#        'Incident Address', 'Street Name', 'Cross Street 1', 'Cross Street 2',
#        'Address Type', 'City', 'Status', 'Due Date',
#        'Resolution Action Updated Date', 'Community Board', 'Borough',
#        'X Coordinate (State Plane)', 'Y Coordinate (State Plane)',
#        'Park Facility Name', 'Park Borough', 'School Name', 'School Number',
#        'School Region', 'School Code', 'School Phone Number', 'School Address',
#        'School City', 'School State', 'School Zip', 'School Not Found',
#        'Latitude', 'Longitude', 'Location', 'num_missing'],
#       dtype='object')

# %%
df2_nomissing['Borough'].hist(bins=10)

df2_nomissing.boxplot(column=['Borough'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-33-80dbcd1a493c> in <cell line: 3>()
#       1 df2_nomissing['Borough'].hist(bins=10)
#       2
# ----> 3 df2_nomissing.boxplot(column=['Borough'])
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, backend, **kwargs)
#     514 ):
#     515     plot_backend = _get_plot_backend(backend)
# --> 516     return plot_backend.boxplot_frame(
#     517         self,
#     518         column=column,
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_matplotlib/boxplot.py in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#     456     import matplotlib.pyplot as plt
#     457
# --> 458     ax = boxplot(
#     459         self,
#     460         column=column,
#
# ...

# %%
# Use the describe() method
df2_nomissing['Borough'].describe()
# Out:
# count       101914
# unique           6
# top       BROOKLYN
# freq         34673
# Name: Borough, dtype: object

# %%
# Plot a bar chart
df2_nomissing['Borough'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# Which of the three techniques helped you find any outliers? Now that you have found outliers, what will you do to solve the problem?

# %%
# Handle any outliers in your dataframe

#There shouldn't be any unspecified Boroughs I would remove those

df2_unspecified = df2_nomissing.drop(df2_nomissing[df2_nomissing['Borough'] == 'Unspecified'].index)

df2_unspecified['Borough'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# ## Unnecessary Data
#
# Unnecessary data could be duplicates, irrelevant, or any uninformative data. Dive into each type of unnecessary data to see if there is any in the data set. Make sure to make note of how you would handle each type of unnecessary data.

# %%
# Look for any irrelevant data in the dataframe. How will you handle it?

num_rows = len(df2_unspecified)

for col in df2_unspecified.columns:
    cnts = df2_unspecified[col].value_counts(dropna=False)
    top_pct = (cnts/num_rows).iloc[0]

    if top_pct >= 1:
        print('{0}: {1:.2f}%'.format(col, top_pct*100))
        print(cnts)
        print()
        df2_unspecified = df2_unspecified.drop(col, axis=1) #I'll drop those

# %%
df2_unspecified.columns
# Out:
# Index(['Unique Key', 'Created Date', 'Closed Date', 'Location Type',
#        'Incident Zip', 'Incident Address', 'Street Name', 'Cross Street 1',
#        'Cross Street 2', 'Address Type', 'City', 'Status', 'Due Date',
#        'Resolution Action Updated Date', 'Community Board', 'Borough',
#        'X Coordinate (State Plane)', 'Y Coordinate (State Plane)',
#        'Park Borough', 'School Not Found', 'Latitude', 'Longitude', 'Location',
#        'num_missing'],
#       dtype='object')

# %%
# Look for duplicates. How will you handle any duplicates?

has_duplicates = df2_unspecified['Unique Key'].duplicated().any()

if has_duplicates:
    print("Duplicate values exist in the 'Unique Key' column.")
else:
    print("No duplicate values found in the 'Unique Key' column.")
# Out:
# No duplicate values found in the 'Unique Key' column.

# %%
# Think about what data in the dataframe may be uninformative. Make note here of what situations may render data uninformative and how you would handle it?

#I'm inclined to drop all uninformative / repeated data, but that's only useful for datasets that are static. If you just happen to only interview men at the beginning of your research, the gender column will become relevant once you interview someone who isn't a man.

# %% [markdown]
# ## Inconsistent Data
#
# Inconsistent data is anything that messes with your model. This is likely due to inconsistent formatting and can be addressed by re-formatting all values in a column or row.

# %%
# Try to convert all the strings in a column to lower or upper case.

df2_unspecified['Borough'] = df2_unspecified['Borough'].str.lower()
df2_unspecified['Borough'].value_counts(dropna=False)
# Out:
# brooklyn         34673
# manhattan        26803
# bronx            20706
# queens           14811
# staten island     4920
# Name: Borough, dtype: int64
